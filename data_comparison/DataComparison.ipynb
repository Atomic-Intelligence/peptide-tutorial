# %%
from utils import compare_distributions, compare_correlations

# %%
compare_distributions(
    synthetic_csv_path="data/synthetic_data_clinical.csv",
    original_csv_path="data/original_data_clinical.csv",
)

# %%
compare_correlations(
    synthetic_csv_path="data/synthetic_data_clinical.csv",
    original_csv_path="data/original_data_clinical.csv",
)
